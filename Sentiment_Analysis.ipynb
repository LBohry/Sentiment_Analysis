# %% [markdown]
# # *Imports*

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %% [markdown]
# # *Load Data , train on first 500 examples only because of the computation cost of the roberta model*

# %%
df = pd.read_csv('IMDB Dataset.csv')
df = df.head(100)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
print(df.shape)
# Out:
# (100, 2)

# %% [markdown]
# # *Some Ground level NLTK*

# %%
example = df['review'][50]

# %%
example
# Out:
# 'Return to the 36th Chamber is one of those classic Kung-Fu movies which Shaw produces back in the 70s and 80s, whose genre is equivalent to the spaghetti westerns of Hollywood, and the protagonist Gordon Liu, the counterpart to the western\'s Clint Eastwood. Digitally remastered and a new print made for the Fantastic Film Fest, this is "Presented in Shaw Scope", just like the good old days.<br /><br />This film is a simple story of good versus evil, told in 3 acts, which more or less sums up the narrative of martial arts films in that era.<br /><br />Act One sets up the premise. Workers in a dye-mill of a small village are unhappy with their lot, having their wages cut by 20% by incoming manchu gangsters. They can\'t do much about their exploitation because none of them are martial arts skilled to take on the gangsters, and their boss. At first they had a minor success in getting Liu to impersonate a highly skilled Shaolin monk (one of the best comedy sequences), but their rouse got exposed when they pushed the limit of credibility by impersonating one too many times.<br /><br />Act Two shows the protagonist wanting to get back at the mob. However, without real martial arts, he embarks on a journey to Shaolin Temple, to try and infiltrate and learn martial arts on the sly. After some slapstick moments, he finally gets accepted by the abbot (whom he impersonated!) but is disappointed at the teaching methods - kinda like Mr Miyagi\'s style in Karate Kid, but instead of painting fences, he gets to erect scaffoldings all around the temple. Nothing can keep a good man down, and he unwittingly builds strength, endurance and learns kung-fu the unorthodox way.<br /><br />Act Three is where the fight fest begins. With cheesy sound effects, each obvious non-contact on film is given the maximum impact treatment. But it is rather refreshing watching the fight scenes here, with its wide angled shots to highlight clarity and detail between the sparring partners, and the use of slow-motion only to showcase stunts in different angles. You may find the speed of fights a tad too slow, with some pause in between moves, but with Yuen Wo Ping and his style being used ad-nausem in Hollywood flicks, they sure don\'t make fight scenes like they used to! Return to the 36th chamber gets a repeat screening on Monday, so, if you\'re game for a nostalgic trip down memory lane, what are you waiting for?'

# %% [markdown]
# **Tokenization of the words and different syllables**

# %%
tokens = nltk.word_tokenize(example)
tokens[:20]
# Out:
# ['Return',
#  'to',
#  'the',
#  '36th',
#  'Chamber',
#  'is',
#  'one',
#  'of',
#  'those',
#  'classic',
#  'Kung-Fu',
#  'movies',
#  'which',
#  'Shaw',
#  'produces',
#  'back',
#  'in',
#  'the',
#  '70s',
#  'and']

# %% [markdown]
# **Tagging the different Tokens**

# %%
tagged = nltk.pos_tag(tokens)
tagged[:20]
# Out:
# [('Return', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('36th', 'CD'),
#  ('Chamber', 'NNP'),
#  ('is', 'VBZ'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('those', 'DT'),
#  ('classic', 'JJ'),
#  ('Kung-Fu', 'NNP'),
#  ('movies', 'NNS'),
#  ('which', 'WDT'),
#  ('Shaw', 'NNP'),
#  ('produces', 'VBZ'),
#  ('back', 'RB'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('70s', 'CD'),
#  ('and', 'CC')]

# %% [markdown]
# **Putting Tagged Tokens into different Chunks (groups)**

# %%
entities = nltk.chunk.ne_chunk(tagged)
entities.pprint()
# Out:
# (S
#   (GPE Return/NN)
#   to/TO
#   the/DT
#   36th/CD
#   Chamber/NNP
#   is/VBZ
#   one/CD
#   of/IN
#   those/DT
#   classic/JJ
#   Kung-Fu/NNP
#   movies/NNS
#   which/WDT
#   (PERSON Shaw/NNP)
#   produces/VBZ
#   back/RB
#   in/IN
#   the/DT
#   70s/CD
#   and/CC
#   80s/CD
#   ,/,
#   whose/WP$
#   genre/NN
#   is/VBZ
#   equivalent/JJ
#   to/TO
#   the/DT
#   spaghetti/NNS
#   westerns/NNS
#   of/IN
#   (GPE Hollywood/NNP)
#   ,/,
#   and/CC
#   the/DT
#   protagonist/NN
#   (PERSON Gordon/NNP Liu/NNP)
#   ,/,
#   the/DT
#   counterpart/NN
#   to/TO
#   the/DT
#   western/NN
#   's/POS
#   (PERSON Clint/NNP Eastwood/NNP)
#   ./.
#   (PERSON Digitally/NNP)
#   remastered/VBD
#   and/CC
#   a/DT
#   new/JJ
#   print/NN
#   made/VBN
#   for/IN
#   the/DT
#   (ORGANIZATION Fantastic/NNP Film/NNP Fest/NNP)
#   ,/,
#   this/DT
#   is/VBZ
#   ``/``
#   Presented/VBN
#   in/IN
#   (GPE Shaw/NNP)
#   Scope/NNP
#   ''/''
#   ,/,
#   just/RB
#   like/IN
#   the/DT
#   good/JJ
#   old/JJ
#   days./NN
#   </NNP
#   br/NN
#   //NNP
#   >/NNP
#   </NNP
#   br/NN
#   //NNP
#   >/NNP
#   This/DT
#   film/NN
#   is/VBZ
#   a/DT
#   simple/JJ
#   story/NN
#   of/IN
#   good/JJ
#   versus/NN
#   evil/NN
#   ,/,
#   told/VBD
#   in/IN
#   3/CD
#   acts/NNS
#   ,/,
#   which/WDT
#   more/RBR
#   or/CC
#   less/RBR
#   sums/NNS
#   up/IN
#   the/DT
#   narrative/NN
#   of/IN
#   martial/JJ
#   arts/NNS
#   films/NNS
#   in/IN
#   that/DT
#   era./NN
#   </NNP
#   br/NN
#   //NNP
#   >/NNP
#   </NNP
#   br/NN
#   //NNP
#   >/NNP
#   Act/NNP
#   One/NNP
#   sets/VBZ
#   up/RP
#   the/DT
#   premise/NN
#   ./.
#   Workers/NNS
#   in/IN
#   a/DT
#   dye-mill/NN
#   of/IN
#   a/DT
#   small/JJ
#   village/NN
#   are/VBP
#   unhappy/JJ
#   with/IN
#   their/PRP$
#   lot/NN
#   ,/,
#   having/VBG
#   their/PRP$
#   wages/NNS
#   cut/VBN
#   by/IN
#   20/CD
#   %/NN
#   by/IN
#   incoming/VBG
#   manchu/NN
#   gangsters/NNS
#   ./.
#   They/PRP
#   ca/MD
#   n't/RB
#   do/VB
#   much/RB
#   about/IN
#   their/PRP$
#   exploitation/NN
#   because/IN
#   none/NN
#   of/IN
#   them/PRP
#   are/VBP
#   martial/JJ
#   arts/NNS
#   skilled/VBD
#   to/TO
#   take/VB
#   on/IN
#   the/DT
#   gangsters/NNS
#   ,/,
#   and/CC
#   their/PRP$
#   boss/NN
#   ./.
#   At/IN
#   first/JJ
#   they/PRP
#   had/VBD
#   a/DT
#   minor/JJ
#   success/NN
#   in/IN
#   getting/VBG
#   (PERSON Liu/NNP)
#   to/TO
#   impersonate/VB
#   a/DT
#   highly/RB
#   skilled/JJ
#   (PERSON Shaolin/NNP)
#   monk/NN
#   (/(
#   one/CD
#   of/IN
#   the/DT
#   best/JJS
#   comedy/NN
#   sequences/NNS
#   )/)
#   ,/,
#   but/CC
#   their/PRP$
#   rouse/NN
#   got/VBD
#   exposed/VBN
#   when/WRB
#   they/PRP
#   pushed/VBD
#   the/DT
#   limit/NN
#   of/IN
#   credibility/NN
#   by/IN
#   impersonating/VBG
#   one/CD
#   too/RB
#   many/JJ
#   times./NNS
#   </VBP
#   br/JJ
#   //NNP
#   >/NNP
#   </NNP
#   br/NN
#   //NNP
#   >/NNP
#   Act/NNP
#   Two/CD
#   shows/VBZ
#   the/DT
#   protagonist/NN
#   wanting/VBG
#   to/TO
#   get/VB
#   back/RB
#   at/IN
#   the/DT
#   mob/NN
#   ./.
#   However/RB
#   ,/,
#   without/IN
#   real/JJ
#   martial/JJ
#   arts/NNS
#   ,/,
#   he/PRP
#   embarks/VBZ
#   on/IN
#   a/DT
#   journey/NN
#   to/TO
#   (PERSON Shaolin/NNP Temple/NNP)
#   ,/,
#   to/TO
#   try/VB
#   and/CC
#   infiltrate/VB
#   and/CC
#   learn/VB
#   martial/JJ
#   arts/NNS
#   on/IN
#   the/DT
#   sly/NN
#   ./.
#   After/IN
#   some/DT
#   slapstick/JJ
#   moments/NNS
#   ,/,
#   he/PRP
#   finally/RB
#   gets/VBZ
#   accepted/VBN
#   by/IN
#   the/DT
#   abbot/NN
#   (/(
#   whom/WP
#   he/PRP
#   impersonated/VBD
#   !/.
#   )/)
#   but/CC
#   is/VBZ
#   disappointed/VBN
#   at/IN
#   the/DT
#   teaching/VBG
#   methods/NNS
#   -/:
#   kinda/NN
#   like/IN
#   Mr/NNP
#   (PERSON Miyagi/NNP)
#   's/POS
#   style/NN
#   in/IN
#   (GPE Karate/NNP Kid/NNP)
#   ,/,
#   but/CC
#   instead/RB
#   of/IN
#   painting/VBG
#   fences/NNS
#   ,/,
#   he/PRP
#   gets/VBZ
#   to/TO
#   erect/VB
#   scaffoldings/NNS
#   all/DT
#   around/IN
#   the/DT
#   temple/NN
#   ./.
#   Nothing/NN
#   can/MD
#   keep/VB
#   a/DT
#   good/JJ
#   man/NN
#   down/RP
#   ,/,
#   and/CC
#   he/PRP
#   unwittingly/RB
#   builds/VBZ
#   strength/NN
#   ,/,
#   endurance/NN
#   and/CC
#   learns/VBZ
#   kung-fu/NN
#   the/DT
#   unorthodox/JJ
#   way./NN
#   </NNP
#   br/NN
#   //NNP
#   >/NNP
#   </NNP
#   br/NN
#   //NNP
#   >/NNP
#   Act/NNP
#   Three/NNP
#   is/VBZ
#   where/WRB
#   the/DT
#   fight/NN
#   fest/JJS
#   begins/NNS
#   ./.
#   With/IN
#   cheesy/JJ
#   sound/NN
#   effects/NNS
#   ,/,
#   each/DT
#   obvious/JJ
#   non-contact/JJ
#   on/IN
#   film/NN
#   is/VBZ
#   given/VBN
#   the/DT
#   maximum/JJ
#   impact/NN
#   treatment/NN
#   ./.
#   But/CC
#   it/PRP
#   is/VBZ
#   rather/RB
#   refreshing/VBG
#   watching/VBG
#   the/DT
#   fight/NN
#   scenes/NNS
#   here/RB
#   ,/,
#   with/IN
#   its/PRP$
#   wide/JJ
#   angled/JJ
#   shots/NNS
#   to/TO
#   highlight/VB
#   clarity/NN
#   and/CC
#   detail/NN
#   between/IN
#   the/DT
#   sparring/VBG
#   partners/NNS
#   ,/,
#   and/CC
#   the/DT
#   use/NN
#   of/IN
#   slow-motion/NN
#   only/RB
#   to/TO
#   showcase/VB
#   stunts/NNS
#   in/IN
#   different/JJ
#   angles/NNS
#   ./.
#   You/PRP
#   may/MD
#   find/VB
#   the/DT
#   speed/NN
#   of/IN
#   fights/NNS
#   a/DT
#   tad/RB
#   too/RB
#   slow/JJ
#   ,/,
#   with/IN
#   some/DT
#   pause/NN
#   in/IN
#   between/IN
#   moves/NNS
#   ,/,
#   but/CC
#   with/IN
#   (PERSON Yuen/NNP Wo/NNP Ping/NNP)
#   and/CC
#   his/PRP$
#   style/NN
#   being/VBG
#   used/VBN
#   ad-nausem/NN
#   in/IN
#   (GPE Hollywood/NNP)
#   flicks/NNS
#   ,/,
#   they/PRP
#   sure/RB
#   do/VBP
#   n't/RB
#   make/VB
#   fight/JJ
#   scenes/NNS
#   like/IN
#   they/PRP
#   used/VBD
#   to/TO
#   !/.
#   Return/VB
#   to/TO
#   the/DT
#   36th/CD
#   chamber/NN
#   gets/VBZ
#   a/DT
#   repeat/NN
#   screening/VBG
#   on/IN
#   Monday/NNP
#   ,/,
#   so/RB
#   ,/,
#   if/IN
#   you/PRP
#   're/VBP
#   game/NN
#   for/IN
#   a/DT
#   nostalgic/JJ
#   trip/NN
#   down/RP
#   memory/NN
#   lane/NN
#   ,/,
#   what/WP
#   are/VBP
#   you/PRP
#   waiting/VBG
#   for/IN
#   ?/.)

# %% [markdown]
# # *Old School Approach : VADER Seniment Scoring*

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# **Model Vibe Check !**

# %%
sia.polarity_scores('VIVA TOUNIZI LETS GOOOO')
# Out:
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
sia.polarity_scores('FRANCA MA TERBA7CH >:(')
# Out:
# {'neg': 0.552, 'neu': 0.448, 'pos': 0.0, 'compound': -0.5719}

# %% [markdown]
# # *VADER Model on the whole dataset*

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['review']
    myid = i
    res[i] = sia.polarity_scores(text)
res
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# {0: {'neg': 0.203, 'neu': 0.748, 'pos': 0.048, 'compound': -0.9951},
#  1: {'neg': 0.053, 'neu': 0.776, 'pos': 0.172, 'compound': 0.9641},
#  2: {'neg': 0.094, 'neu': 0.714, 'pos': 0.192, 'compound': 0.9605},
#  3: {'neg': 0.138, 'neu': 0.797, 'pos': 0.065, 'compound': -0.9213},
#  4: {'neg': 0.052, 'neu': 0.801, 'pos': 0.147, 'compound': 0.9744},
#  5: {'neg': 0.017, 'neu': 0.758, 'pos': 0.225, 'compound': 0.9828},
#  6: {'neg': 0.024, 'neu': 0.871, 'pos': 0.104, 'compound': 0.9022},
#  7: {'neg': 0.149, 'neu': 0.654, 'pos': 0.197, 'compound': 0.8596},
#  8: {'neg': 0.166, 'neu': 0.662, 'pos': 0.172, 'compound': 0.2362},
#  9: {'neg': 0.094, 'neu': 0.531, 'pos': 0.375, 'compound': 0.9149},
#  10: {'neg': 0.084, 'neu': 0.696, 'pos': 0.221, 'compound': 0.9482},
#  11: {'neg': 0.107, 'neu': 0.779, 'pos': 0.114, 'compound': 0.5223},
#  12: {'neg': 0.145, 'neu': 0.75, 'pos': 0.105, 'compound': -0.9721},
#  13: {'neg': 0.086, 'neu': 0.795, 'pos': 0.12, 'compound': 0.3425},
#  14: {'neg': 0.117, 'neu': 0.713, 'pos': 0.17, 'compound': 0.6168},
#  15: {'neg': 0.145, 'neu': 0.745, 'pos': 0.109, 'compound': -0.6993},
#  16: {'neg': 0.113, 'neu': 0.761, 'pos': 0.127, 'compound': 0.3506},
#  17: {'neg': 0.18, 'neu': 0.778, 'pos': 0.043, 'compound': -0.9868},
#  18: {'neg': 0.044, 'neu': 0.872, 'pos': 0.084, 'compound': 0.6518},
#  19: {'neg': 0.055, 'neu': 0.788, 'pos': 0.157, 'compound': 0.945},
#  20: {'neg': 0.154, 'neu': 0.706, 'pos': 0.141, 'compound': 0.5425},
#  21: {'neg': 0.198, 'neu': 0.716, 'pos': 0.086, 'compound': -0.9755},
#  22: {'neg': 0.04, 'neu': 0.794, 'pos': 0.166, 'compound': 0.7948},
#  23: {'neg': 0.114, 'neu': 0.724, 'pos': 0.162, 'compound': 0.899},
#  24: {'neg': 0.122, 'neu': 0.797, 'pos': 0.082, 'compound': -0.7602},
#  25: {'neg': 0.106, 'neu': 0.667, 'pos': 0.227, 'compound': 0.954},
#  26: {'neg': 0.082, 'neu': 0.748, 'pos': 0.17, 'compound': 0.9962},
#  27: {'neg': 0.184, 'neu': 0.672, 'pos': 0.144, 'compound': -0.8481},
#  28: {'neg': 0.24, 'neu': 0.583, 'pos': 0.177, 'compound': -0.9208},
#  29: {'neg': 0.158, 'neu': 0.745, 'pos': 0.097, 'compound': -0.987},
#  30: {'neg': 0.143, 'neu': 0.799, 'pos': 0.058, 'compound': -0.9907},
#  31: {'neg': 0.119, 'neu': 0.781, 'pos': 0.1, 'compound': -0.6485},
#  32: {'neg': 0.218, 'neu': 0.702, 'pos': 0.08, 'compound': -0.9604},
#  33: {'neg': 0.039, 'neu': 0.824, 'pos': 0.137, 'compound': 0.9971},
#  34: {'neg': 0.137, 'neu': 0.715, 'pos': 0.148, 'compound': 0.7133},
#  35: {'neg': 0.13, 'neu': 0.763, 'pos': 0.107, 'compound': -0.9399},
#  36: {'neg': 0.221, 'neu': 0.731, 'pos': 0.048, 'compound': -0.962},
#  37: {'neg': 0.163, 'neu': 0.76, 'pos': 0.077, 'compound': -0.9847},
#  38: {'neg': 0.05, 'neu': 0.7, 'pos': 0.25, 'compound': 0.9838},
#  39: {'neg': 0.081, 'neu': 0.747, 'pos': 0.173, 'compound': 0.9797},
#  40: {'neg': 0.104, 'neu': 0.79, 'pos': 0.106, 'compound': 0.0854},
#  41: {'neg': 0.03, 'neu': 0.781, 'pos': 0.189, 'compound': 0.9858},
#  42: {'neg': 0.144, 'neu': 0.732, 'pos': 0.124, 'compound': -0.4678},
#  43: {'neg': 0.046, 'neu': 0.814, 'pos': 0.14, 'compound': 0.9818},
#  44: {'neg': 0.026, 'neu': 0.846, 'pos': 0.128, 'compound': 0.9182},
#  45: {'neg': 0.016, 'neu': 0.891, 'pos': 0.093, 'compound': 0.9401},
#  46: {'neg': 0.031, 'neu': 0.775, 'pos': 0.194, 'compound': 0.9165},
#  47: {'neg': 0.054, 'neu': 0.917, 'pos': 0.029, 'compound': -0.68},
#  48: {'neg': 0.101, 'neu': 0.797, 'pos': 0.102, 'compound': -0.382},
#  49: {'neg': 0.141, 'neu': 0.695, 'pos': 0.165, 'compound': 0.2152},
#  50: {'neg': 0.057, 'neu': 0.85, 'pos': 0.094, 'compound': 0.9396},
#  51: {'neg': 0.101, 'neu': 0.746, 'pos': 0.153, 'compound': 0.9893},
#  52: {'neg': 0.147, 'neu': 0.768, 'pos': 0.085, 'compound': -0.9274},
#  53: {'neg': 0.05, 'neu': 0.825, 'pos': 0.125, 'compound': 0.7416},
#  54: {'neg': 0.193, 'neu': 0.699, 'pos': 0.108, 'compound': -0.968},
#  55: {'neg': 0.098, 'neu': 0.819, 'pos': 0.083, 'compound': -0.3696},
#  56: {'neg': 0.122, 'neu': 0.832, 'pos': 0.046, 'compound': -0.9477},
#  57: {'neg': 0.114, 'neu': 0.741, 'pos': 0.145, 'compound': 0.7648},
#  58: {'neg': 0.133, 'neu': 0.73, 'pos': 0.136, 'compound': -0.8235},
#  59: {'neg': 0.088, 'neu': 0.755, 'pos': 0.157, 'compound': 0.992},
#  60: {'neg': 0.091, 'neu': 0.753, 'pos': 0.157, 'compound': 0.9139},
#  61: {'neg': 0.047, 'neu': 0.921, 'pos': 0.031, 'compound': -0.3699},
#  62: {'neg': 0.021, 'neu': 0.862, 'pos': 0.117, 'compound': 0.7747},
#  63: {'neg': 0.079, 'neu': 0.876, 'pos': 0.045, 'compound': -0.168},
#  64: {'neg': 0.116, 'neu': 0.772, 'pos': 0.111, 'compound': -0.4442},
#  65: {'neg': 0.09, 'neu': 0.785, 'pos': 0.124, 'compound': 0.6803},
#  66: {'neg': 0.123, 'neu': 0.759, 'pos': 0.118, 'compound': -0.6416},
#  67: {'neg': 0.014, 'neu': 0.731, 'pos': 0.255, 'compound': 0.9902},
#  68: {'neg': 0.045, 'neu': 0.885, 'pos': 0.069, 'compound': 0.7073},
#  69: {'neg': 0.057, 'neu': 0.833, 'pos': 0.11, 'compound': 0.9422},
#  70: {'neg': 0.072, 'neu': 0.737, 'pos': 0.19, 'compound': 0.9837},
#  71: {'neg': 0.094, 'neu': 0.715, 'pos': 0.192, 'compound': 0.9852},
#  72: {'neg': 0.074, 'neu': 0.832, 'pos': 0.094, 'compound': 0.6441},
#  73: {'neg': 0.043, 'neu': 0.783, 'pos': 0.175, 'compound': 0.9813},
#  74: {'neg': 0.033, 'neu': 0.871, 'pos': 0.096, 'compound': 0.9382},
#  75: {'neg': 0.021, 'neu': 0.735, 'pos': 0.244, 'compound': 0.9847},
#  76: {'neg': 0.129, 'neu': 0.771, 'pos': 0.1, 'compound': -0.8963},
#  77: {'neg': 0.171, 'neu': 0.735, 'pos': 0.094, 'compound': -0.9973},
#  78: {'neg': 0.075, 'neu': 0.816, 'pos': 0.109, 'compound': 0.4082},
#  79: {'neg': 0.07, 'neu': 0.837, 'pos': 0.093, 'compound': 0.8498},
#  80: {'neg': 0.039, 'neu': 0.81, 'pos': 0.151, 'compound': 0.9714},
#  81: {'neg': 0.166, 'neu': 0.756, 'pos': 0.078, 'compound': -0.9504},
#  82: {'neg': 0.162, 'neu': 0.69, 'pos': 0.148, 'compound': -0.8837},
#  83: {'neg': 0.133, 'neu': 0.721, 'pos': 0.146, 'compound': 0.5907},
#  84: {'neg': 0.186, 'neu': 0.712, 'pos': 0.102, 'compound': -0.8489},
#  85: {'neg': 0.159, 'neu': 0.758, 'pos': 0.083, 'compound': -0.9123},
#  86: {'neg': 0.105, 'neu': 0.791, 'pos': 0.104, 'compound': -0.1012},
#  87: {'neg': 0.116, 'neu': 0.787, 'pos': 0.097, 'compound': -0.4623},
#  88: {'neg': 0.152, 'neu': 0.718, 'pos': 0.13, 'compound': -0.7228},
#  89: {'neg': 0.148, 'neu': 0.748, 'pos': 0.104, 'compound': -0.9659},
#  90: {'neg': 0.033, 'neu': 0.851, 'pos': 0.116, 'compound': 0.9311},
#  91: {'neg': 0.068, 'neu': 0.855, 'pos': 0.077, 'compound': -0.0516},
#  92: {'neg': 0.036, 'neu': 0.814, 'pos': 0.151, 'compound': 0.9943},
#  93: {'neg': 0.052, 'neu': 0.736, 'pos': 0.212, 'compound': 0.9818},
#  94: {'neg': 0.033, 'neu': 0.843, 'pos': 0.125, 'compound': 0.9272},
#  95: {'neg': 0.086, 'neu': 0.735, 'pos': 0.179, 'compound': 0.9826},
#  96: {'neg': 0.167, 'neu': 0.735, 'pos': 0.099, 'compound': -0.9434},
#  97: {'neg': 0.324, 'neu': 0.547, 'pos': 0.13, 'compound': -0.9882},
#  98: {'neg': 0.203, 'neu': 0.729, 'pos': 0.068, 'compound': -0.9876},
#  99: {'neg': 0.064, 'neu': 0.81, 'pos': 0.127, 'compound': 0.9831}}

# %%
vaders = pd.DataFrame(res).T
vaders = vaders.reset_index().rename(columns={'index': 'Movie Id'})
vaders
# Out:
#     Movie Id    neg    neu    pos  compound
# 0          0  0.203  0.748  0.048   -0.9951
# 1          1  0.053  0.776  0.172    0.9641
# 2          2  0.094  0.714  0.192    0.9605
# 3          3  0.138  0.797  0.065   -0.9213
# 4          4  0.052  0.801  0.147    0.9744
# ..       ...    ...    ...    ...       ...
# 95        95  0.086  0.735  0.179    0.9826
# 96        96  0.167  0.735  0.099   -0.9434
# 97        97  0.324  0.547  0.130   -0.9882
# 98        98  0.203  0.729  0.068   -0.9876
# 99        99  0.064  0.810  0.127    0.9831
#
# [100 rows x 5 columns]

# %% [markdown]
# # *Installation of Transformers*

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 4.2 MB/s
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.11.0-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 73.6 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 39.4 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.10.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.11.0 tokenizers-0.13.2 transformers-4.24.0

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %% [markdown]
# # *Modern Approach : Roberta Sentiment Analysis*

# %% [markdown]
# # *Download of the Pre-trained Weights of the Roberta Model*

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)
# Out:
# Downloading:   0%|          | 0.00/747 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/499M [00:00<?, ?B/s]

# %% [markdown]
# # *Tokenization + Fitting the model on our data*
# Transforming the output to a numpy array in order to perform a softmax activation function

# %%
def polarity_scores_roberta(example):
    encoded_text = tokenizer(example, return_tensors='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores = softmax(scores)
    scores_dict = {
        'Roberta_Negative_Review' : scores[0],
        'Roberta_Neutral_Review' : scores[1],
        'Roberta_Positive_Review' : scores[2]
    }
    return scores_dict

# %% [markdown]
# **Model Vibe Check !**

# %%
polarity_scores_roberta("VIVA TOUNIZI LETS GOOOO")
# Out:
# {'Roberta_Negative_Review': 0.01409524,
#  'Roberta_Neutral_Review': 0.26885659,
#  'Roberta_Positive_Review': 0.71704817}

# %%
polarity_scores_roberta("FRANCA MA TERBA7CH >:(")
# Out:
# {'Roberta_Negative_Review': 0.5431578,
#  'Roberta_Neutral_Review': 0.43174478,
#  'Roberta_Positive_Review': 0.025097357}

# %%
polarity_scores_roberta("n3adlou maa franca nerb7ou australia netrach7ou !")
# Out:
# {'Roberta_Negative_Review': 0.07010637,
#  'Roberta_Neutral_Review': 0.8533582,
#  'Roberta_Positive_Review': 0.07653542}

# %% [markdown]
# # *Iterating Over the Dataset And Analysing each review*
# the roberta models breaks on some iterations due to long reviews

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    try:
        text = row['review']
        myid = i
               
        roberta_result = polarity_scores_roberta(text)
        
        res[i] = roberta_result
    except RuntimeError:
        print(f'Broke for id {i}')
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Broke for id 12
# Broke for id 26
# Broke for id 29
# Broke for id 30
# Broke for id 33
# Broke for id 48
# Broke for id 50
# Broke for id 51
# Broke for id 58
# Broke for id 59
# Broke for id 77
# Broke for id 92
# Broke for id 99

# %%
res
# Out:
# {0: {'Roberta_Negative_Review': 0.33979195,
#   'Roberta_Neutral_Review': 0.46273753,
#   'Roberta_Positive_Review': 0.19747041},
#  1: {'Roberta_Negative_Review': 0.004337342,
#   'Roberta_Neutral_Review': 0.039048094,
#   'Roberta_Positive_Review': 0.95661455},
#  2: {'Roberta_Negative_Review': 0.08847477,
#   'Roberta_Neutral_Review': 0.26314417,
#   'Roberta_Positive_Review': 0.6483811},
#  3: {'Roberta_Negative_Review': 0.7551167,
#   'Roberta_Neutral_Review': 0.21164009,
#   'Roberta_Positive_Review': 0.033243094},
#  4: {'Roberta_Negative_Review': 0.024545873,
#   'Roberta_Neutral_Review': 0.22359842,
#   'Roberta_Positive_Review': 0.75185555},
#  5: {'Roberta_Negative_Review': 0.006577765,
#   'Roberta_Neutral_Review': 0.03370466,
#   'Roberta_Positive_Review': 0.9597175},
#  6: {'Roberta_Negative_Review': 0.05034035,
#   'Roberta_Neutral_Review': 0.39188135,
#   'Roberta_Positive_Review': 0.5577783},
#  7: {'Roberta_Negative_Review': 0.8877086,
#   'Roberta_Neutral_Review': 0.090388015,
#   'Roberta_Positive_Review': 0.021903407},
#  8: {'Roberta_Negative_Review': 0.91769475,
#   'Roberta_Neutral_Review': 0.06858954,
#   'Roberta_Positive_Review': 0.013715745},
#  9: {'Roberta_Negative_Review': 0.0032279883,
#   'Roberta_Neutral_Review': 0.018525878,
#   'Roberta_Positive_Review': 0.978246},
#  10: {'Roberta_Negative_Review': 0.11633749,
#   'Roberta_Neutral_Review': 0.33106047,
#   'Roberta_Positive_Review': 0.552602},
#  11: {'Roberta_Negative_Review': 0.24681357,
#   'Roberta_Neutral_Review': 0.37173122,
#   'Roberta_Positive_Review': 0.38145524},
#  13: {'Roberta_Negative_Review': 0.74719846,
#   'Roberta_Neutral_Review': 0.2168073,
#   'Roberta_Positive_Review': 0.03599418},
#  14: {'Roberta_Negative_Review': 0.0037218516,
#   'Roberta_Neutral_Review': 0.021488853,
#   'Roberta_Positive_Review': 0.9747894},
#  15: {'Roberta_Negative_Review': 0.9025109,
#   'Roberta_Neutral_Review': 0.086676754,
#   'Roberta_Positive_Review': 0.010812495},
#  16: {'Roberta_Negative_Review': 0.32996297,
#   'Roberta_Neutral_Review': 0.46636373,
#   'Roberta_Positive_Review': 0.20367332},
#  17: {'Roberta_Negative_Review': 0.94888234,
#   'Roberta_Neutral_Review': 0.046240985,
#   'Roberta_Positive_Review': 0.004876772},
#  18: {'Roberta_Negative_Review': 0.3313388,
#   'Roberta_Neutral_Review': 0.52452755,
#   'Roberta_Positive_Review': 0.14413364},
#  19: {'Roberta_Negative_Review': 0.71488255,
#   'Roberta_Neutral_Review': 0.24405168,
#   'Roberta_Positive_Review': 0.041065812},
#  20: {'Roberta_Negative_Review': 0.28926256,
#   'Roberta_Neutral_Review': 0.44554472,
#   'Roberta_Positive_Review': 0.2651928},
#  21: {'Roberta_Negative_Review': 0.9779352,
#   'Roberta_Neutral_Review': 0.018928839,
#   'Roberta_Positive_Review': 0.0031360763},
#  22: {'Roberta_Negative_Review': 0.0032595822,
#   'Roberta_Neutral_Review': 0.016052138,
#   'Roberta_Positive_Review': 0.98068815},
#  23: {'Roberta_Negative_Review': 0.79129964,
#   'Roberta_Neutral_Review': 0.15820636,
#   'Roberta_Positive_Review': 0.05049395},
#  24: {'Roberta_Negative_Review': 0.85821366,
#   'Roberta_Neutral_Review': 0.11726915,
#   'Roberta_Positive_Review': 0.02451712},
#  25: {'Roberta_Negative_Review': 0.060101077,
#   'Roberta_Neutral_Review': 0.27281123,
#   'Roberta_Positive_Review': 0.6670878},
#  27: {'Roberta_Negative_Review': 0.83798516,
#   'Roberta_Neutral_Review': 0.14058465,
#   'Roberta_Positive_Review': 0.021430159},
#  28: {'Roberta_Negative_Review': 0.97054803,
#   'Roberta_Neutral_Review': 0.024958251,
#   'Roberta_Positive_Review': 0.0044938177},
#  31: {'Roberta_Negative_Review': 0.11400004,
#   'Roberta_Neutral_Review': 0.46802473,
#   'Roberta_Positive_Review': 0.4179753},
#  32: {'Roberta_Negative_Review': 0.4885479,
#   'Roberta_Neutral_Review': 0.3330465,
#   'Roberta_Positive_Review': 0.17840554},
#  34: {'Roberta_Negative_Review': 0.74275315,
#   'Roberta_Neutral_Review': 0.19644888,
#   'Roberta_Positive_Review': 0.060797874},
#  35: {'Roberta_Negative_Review': 0.559325,
#   'Roberta_Neutral_Review': 0.3569781,
#   'Roberta_Positive_Review': 0.08369682},
#  36: {'Roberta_Negative_Review': 0.96514404,
#   'Roberta_Neutral_Review': 0.031239282,
#   'Roberta_Positive_Review': 0.0036167307},
#  37: {'Roberta_Negative_Review': 0.7727644,
#   'Roberta_Neutral_Review': 0.20132737,
#   'Roberta_Positive_Review': 0.02590822},
#  38: {'Roberta_Negative_Review': 0.17523539,
#   'Roberta_Neutral_Review': 0.2690206,
#   'Roberta_Positive_Review': 0.555744},
#  39: {'Roberta_Negative_Review': 0.79734993,
#   'Roberta_Neutral_Review': 0.17731535,
#   'Roberta_Positive_Review': 0.02533471},
#  40: {'Roberta_Negative_Review': 0.8547,
#   'Roberta_Neutral_Review': 0.12547676,
#   'Roberta_Positive_Review': 0.019823164},
#  41: {'Roberta_Negative_Review': 0.008102008,
#   'Roberta_Neutral_Review': 0.09048482,
#   'Roberta_Positive_Review': 0.901413},
#  42: {'Roberta_Negative_Review': 0.82282436,
#   'Roberta_Neutral_Review': 0.15525876,
#   'Roberta_Positive_Review': 0.021916874},
#  43: {'Roberta_Negative_Review': 0.71852994,
#   'Roberta_Neutral_Review': 0.23779061,
#   'Roberta_Positive_Review': 0.04367933},
#  44: {'Roberta_Negative_Review': 0.1433462,
#   'Roberta_Neutral_Review': 0.4178944,
#   'Roberta_Positive_Review': 0.43875936},
#  45: {'Roberta_Negative_Review': 0.014722989,
#   'Roberta_Neutral_Review': 0.102497734,
#   'Roberta_Positive_Review': 0.88277924},
#  46: {'Roberta_Negative_Review': 0.6720444,
#   'Roberta_Neutral_Review': 0.2732199,
#   'Roberta_Positive_Review': 0.054735616},
#  47: {'Roberta_Negative_Review': 0.5483824,
#   'Roberta_Neutral_Review': 0.38960016,
#   'Roberta_Positive_Review': 0.062017582},
#  49: {'Roberta_Negative_Review': 0.36273095,
#   'Roberta_Neutral_Review': 0.39873725,
#   'Roberta_Positive_Review': 0.2385317},
#  52: {'Roberta_Negative_Review': 0.043381263,
#   'Roberta_Neutral_Review': 0.2717683,
#   'Roberta_Positive_Review': 0.68485045},
#  53: {'Roberta_Negative_Review': 0.05164413,
#   'Roberta_Neutral_Review': 0.17523994,
#   'Roberta_Positive_Review': 0.773116},
#  54: {'Roberta_Negative_Review': 0.8927543,
#   'Roberta_Neutral_Review': 0.09760979,
#   'Roberta_Positive_Review': 0.009635772},
#  55: {'Roberta_Negative_Review': 0.5975118,
#   'Roberta_Neutral_Review': 0.33082077,
#   'Roberta_Positive_Review': 0.07166744},
#  56: {'Roberta_Negative_Review': 0.40475157,
#   'Roberta_Neutral_Review': 0.4018795,
#   'Roberta_Positive_Review': 0.19336876},
#  57: {'Roberta_Negative_Review': 0.9190562,
#   'Roberta_Neutral_Review': 0.07234078,
#   'Roberta_Positive_Review': 0.008602951},
#  60: {'Roberta_Negative_Review': 0.3818074,
#   'Roberta_Neutral_Review': 0.42138064,
#   'Roberta_Positive_Review': 0.19681202},
#  61: {'Roberta_Negative_Review': 0.9427434,
#   'Roberta_Neutral_Review': 0.05261109,
#   'Roberta_Positive_Review': 0.0046455865},
#  62: {'Roberta_Negative_Review': 0.007924771,
#   'Roberta_Neutral_Review': 0.045686495,
#   'Roberta_Positive_Review': 0.9463888},
#  63: {'Roberta_Negative_Review': 0.9411109,
#   'Roberta_Neutral_Review': 0.05316558,
#   'Roberta_Positive_Review': 0.0057234433},
#  64: {'Roberta_Negative_Review': 0.76945114,
#   'Roberta_Neutral_Review': 0.19876209,
#   'Roberta_Positive_Review': 0.03178677},
#  65: {'Roberta_Negative_Review': 0.20438008,
#   'Roberta_Neutral_Review': 0.5221729,
#   'Roberta_Positive_Review': 0.27344695},
#  66: {'Roberta_Negative_Review': 0.45774493,
#   'Roberta_Neutral_Review': 0.435585,
#   'Roberta_Positive_Review': 0.10667014},
#  67: {'Roberta_Negative_Review': 0.08713727,
#   'Roberta_Neutral_Review': 0.2871537,
#   'Roberta_Positive_Review': 0.62570906},
#  68: {'Roberta_Negative_Review': 0.54513776,
#   'Roberta_Neutral_Review': 0.38112146,
#   'Roberta_Positive_Review': 0.07374084},
#  69: {'Roberta_Negative_Review': 0.40168142,
#   'Roberta_Neutral_Review': 0.43447584,
#   'Roberta_Positive_Review': 0.16384278},
#  70: {'Roberta_Negative_Review': 0.6324403,
#   'Roberta_Neutral_Review': 0.26734918,
#   'Roberta_Positive_Review': 0.10021045},
#  71: {'Roberta_Negative_Review': 0.43296242,
#   'Roberta_Neutral_Review': 0.36055428,
#   'Roberta_Positive_Review': 0.2064833},
#  72: {'Roberta_Negative_Review': 0.047615703,
#   'Roberta_Neutral_Review': 0.20404828,
#   'Roberta_Positive_Review': 0.748336},
#  73: {'Roberta_Negative_Review': 0.027260482,
#   'Roberta_Neutral_Review': 0.26411504,
#   'Roberta_Positive_Review': 0.7086245},
#  74: {'Roberta_Negative_Review': 0.15937287,
#   'Roberta_Neutral_Review': 0.48104072,
#   'Roberta_Positive_Review': 0.35958636},
#  75: {'Roberta_Negative_Review': 0.026369533,
#   'Roberta_Neutral_Review': 0.11574825,
#   'Roberta_Positive_Review': 0.8578822},
#  76: {'Roberta_Negative_Review': 0.66567975,
#   'Roberta_Neutral_Review': 0.3056754,
#   'Roberta_Positive_Review': 0.028644864},
#  78: {'Roberta_Negative_Review': 0.7341607,
#   'Roberta_Neutral_Review': 0.2272433,
#   'Roberta_Positive_Review': 0.038595848},
#  79: {'Roberta_Negative_Review': 0.013828626,
#   'Roberta_Neutral_Review': 0.10051051,
#   'Roberta_Positive_Review': 0.88566095},
#  80: {'Roberta_Negative_Review': 0.0268145,
#   'Roberta_Neutral_Review': 0.11846688,
#   'Roberta_Positive_Review': 0.85471857},
#  81: {'Roberta_Negative_Review': 0.9216948,
#   'Roberta_Neutral_Review': 0.06934983,
#   'Roberta_Positive_Review': 0.00895532},
#  82: {'Roberta_Negative_Review': 0.8084991,
#   'Roberta_Neutral_Review': 0.15993492,
#   'Roberta_Positive_Review': 0.031566024},
#  83: {'Roberta_Negative_Review': 0.877801,
#   'Roberta_Neutral_Review': 0.10750761,
#   'Roberta_Positive_Review': 0.014691535},
#  84: {'Roberta_Negative_Review': 0.9758892,
#   'Roberta_Neutral_Review': 0.02102113,
#   'Roberta_Positive_Review': 0.0030896354},
#  85: {'Roberta_Negative_Review': 0.9808668,
#   'Roberta_Neutral_Review': 0.016536972,
#   'Roberta_Positive_Review': 0.0025962885},
#  86: {'Roberta_Negative_Review': 0.37397283,
#   'Roberta_Neutral_Review': 0.45256665,
#   'Roberta_Positive_Review': 0.17346065},
#  87: {'Roberta_Negative_Review': 0.5801263,
#   'Roberta_Neutral_Review': 0.32993132,
#   'Roberta_Positive_Review': 0.089942545},
#  88: {'Roberta_Negative_Review': 0.7237845,
#   'Roberta_Neutral_Review': 0.24307631,
#   'Roberta_Positive_Review': 0.033139143},
#  89: {'Roberta_Negative_Review': 0.564644,
#   'Roberta_Neutral_Review': 0.35569933,
#   'Roberta_Positive_Review': 0.07965662},
#  90: {'Roberta_Negative_Review': 0.0020274578,
#   'Roberta_Neutral_Review': 0.028448526,
#   'Roberta_Positive_Review': 0.96952397},
#  91: {'Roberta_Negative_Review': 0.8376129,
#   'Roberta_Neutral_Review': 0.13871731,
#   'Roberta_Positive_Review': 0.023669606},
#  93: {'Roberta_Negative_Review': 0.012106279,
#   'Roberta_Neutral_Review': 0.2425972,
#   'Roberta_Positive_Review': 0.74529654},
#  94: {'Roberta_Negative_Review': 0.42204875,
#   'Roberta_Neutral_Review': 0.46826288,
#   'Roberta_Positive_Review': 0.10968823},
#  95: {'Roberta_Negative_Review': 0.038287643,
#   'Roberta_Neutral_Review': 0.17748567,
#   'Roberta_Positive_Review': 0.7842267},
#  96: {'Roberta_Negative_Review': 0.41143638,
#   'Roberta_Neutral_Review': 0.41244462,
#   'Roberta_Positive_Review': 0.17611891},
#  97: {'Roberta_Negative_Review': 0.8421043,
#   'Roberta_Neutral_Review': 0.12051555,
#   'Roberta_Positive_Review': 0.03738003},
#  98: {'Roberta_Negative_Review': 0.9445878,
#   'Roberta_Neutral_Review': 0.049333654,
#   'Roberta_Positive_Review': 0.0060785552}}

# %% [markdown]
# # ***Comparison of Vader and roBERTa***

# %%
res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    try:
        text = row['review']
        myid = i
        vader_result = sia.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items():
            vader_result_rename[f"vader_{key}"] = value
        roberta_result = polarity_scores_roberta(text)
        both = {**vader_result_rename, **roberta_result}
        res[myid] = both
    except RuntimeError:
        print(f'Broke for id {i}')

res
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Broke for id 12
# Broke for id 26
# Broke for id 29
# Broke for id 30
# Broke for id 33
# Broke for id 48
# Broke for id 50
# Broke for id 51
# Broke for id 58
# Broke for id 59
# Broke for id 77
# Broke for id 92
# Broke for id 99
# {0: {'vader_neg': 0.203,
#   'vader_neu': 0.748,
#   'vader_pos': 0.048,
#   'vader_compound': -0.9951,
#   'Roberta_Negative_Review': 0.33979195,
#   'Roberta_Neutral_Review': 0.46273753,
#   'Roberta_Positive_Review': 0.19747041},
#  1: {'vader_neg': 0.053,
#   'vader_neu': 0.776,
#   'vader_pos': 0.172,
#   'vader_compound': 0.9641,
#   'Roberta_Negative_Review': 0.004337342,
#   'Roberta_Neutral_Review': 0.039048094,
#   'Roberta_Positive_Review': 0.95661455},
#  2: {'vader_neg': 0.094,
#   'vader_neu': 0.714,
#   'vader_pos': 0.192,
#   'vader_compound': 0.9605,
#   'Roberta_Negative_Review': 0.08847477,
#   'Roberta_Neutral_Review': 0.26314417,
#   'Roberta_Positive_Review': 0.6483811},
#  3: {'vader_neg': 0.138,
#   'vader_neu': 0.797,
#   'vader_pos': 0.065,
#   'vader_compound': -0.9213,
#   'Roberta_Negative_Review': 0.7551167,
#   'Roberta_Neutral_Review': 0.21164009,
#   'Roberta_Positive_Review': 0.033243094},
#  4: {'vader_neg': 0.052,
#   'vader_neu': 0.801,
#   'vader_pos': 0.147,
#   'vader_compound': 0.9744,
#   'Roberta_Negative_Review': 0.024545873,
#   'Roberta_Neutral_Review': 0.22359842,
#   'Roberta_Positive_Review': 0.75185555},
#  5: {'vader_neg': 0.017,
#   'vader_neu': 0.758,
#   'vader_pos': 0.225,
#   'vader_compound': 0.9828,
#   'Roberta_Negative_Review': 0.006577765,
#   'Roberta_Neutral_Review': 0.03370466,
#   'Roberta_Positive_Review': 0.9597175},
#  6: {'vader_neg': 0.024,
#   'vader_neu': 0.871,
#   'vader_pos': 0.104,
#   'vader_compound': 0.9022,
#   'Roberta_Negative_Review': 0.05034035,
#   'Roberta_Neutral_Review': 0.39188135,
#   'Roberta_Positive_Review': 0.5577783},
#  7: {'vader_neg': 0.149,
#   'vader_neu': 0.654,
#   'vader_pos': 0.197,
#   'vader_compound': 0.8596,
#   'Roberta_Negative_Review': 0.8877086,
#   'Roberta_Neutral_Review': 0.090388015,
#   'Roberta_Positive_Review': 0.021903407},
#  8: {'vader_neg': 0.166,
#   'vader_neu': 0.662,
#   'vader_pos': 0.172,
#   'vader_compound': 0.2362,
#   'Roberta_Negative_Review': 0.91769475,
#   'Roberta_Neutral_Review': 0.06858954,
#   'Roberta_Positive_Review': 0.013715745},
#  9: {'vader_neg': 0.094,
#   'vader_neu': 0.531,
#   'vader_pos': 0.375,
#   'vader_compound': 0.9149,
#   'Roberta_Negative_Review': 0.0032279883,
#   'Roberta_Neutral_Review': 0.018525878,
#   'Roberta_Positive_Review': 0.978246},
#  10: {'vader_neg': 0.084,
#   'vader_neu': 0.696,
#   'vader_pos': 0.221,
#   'vader_compound': 0.9482,
#   'Roberta_Negative_Review': 0.11633749,
#   'Roberta_Neutral_Review': 0.33106047,
#   'Roberta_Positive_Review': 0.552602},
#  11: {'vader_neg': 0.107,
#   'vader_neu': 0.779,
#   'vader_pos': 0.114,
#   'vader_compound': 0.5223,
#   'Roberta_Negative_Review': 0.24681357,
#   'Roberta_Neutral_Review': 0.37173122,
#   'Roberta_Positive_Review': 0.38145524},
#  13: {'vader_neg': 0.086,
#   'vader_neu': 0.795,
#   'vader_pos': 0.12,
#   'vader_compound': 0.3425,
#   'Roberta_Negative_Review': 0.74719846,
#   'Roberta_Neutral_Review': 0.2168073,
#   'Roberta_Positive_Review': 0.03599418},
#  14: {'vader_neg': 0.117,
#   'vader_neu': 0.713,
#   'vader_pos': 0.17,
#   'vader_compound': 0.6168,
#   'Roberta_Negative_Review': 0.0037218516,
#   'Roberta_Neutral_Review': 0.021488853,
#   'Roberta_Positive_Review': 0.9747894},
#  15: {'vader_neg': 0.145,
#   'vader_neu': 0.745,
#   'vader_pos': 0.109,
#   'vader_compound': -0.6993,
#   'Roberta_Negative_Review': 0.9025109,
#   'Roberta_Neutral_Review': 0.086676754,
#   'Roberta_Positive_Review': 0.010812495},
#  16: {'vader_neg': 0.113,
#   'vader_neu': 0.761,
#   'vader_pos': 0.127,
#   'vader_compound': 0.3506,
#   'Roberta_Negative_Review': 0.32996297,
#   'Roberta_Neutral_Review': 0.46636373,
#   'Roberta_Positive_Review': 0.20367332},
#  17: {'vader_neg': 0.18,
#   'vader_neu': 0.778,
#   'vader_pos': 0.043,
#   'vader_compound': -0.9868,
#   'Roberta_Negative_Review': 0.94888234,
#   'Roberta_Neutral_Review': 0.046240985,
#   'Roberta_Positive_Review': 0.004876772},
#  18: {'vader_neg': 0.044,
#   'vader_neu': 0.872,
#   'vader_pos': 0.084,
#   'vader_compound': 0.6518,
#   'Roberta_Negative_Review': 0.3313388,
#   'Roberta_Neutral_Review': 0.52452755,
#   'Roberta_Positive_Review': 0.14413364},
#  19: {'vader_neg': 0.055,
#   'vader_neu': 0.788,
#   'vader_pos': 0.157,
#   'vader_compound': 0.945,
#   'Roberta_Negative_Review': 0.71488255,
#   'Roberta_Neutral_Review': 0.24405168,
#   'Roberta_Positive_Review': 0.041065812},
#  20: {'vader_neg': 0.154,
#   'vader_neu': 0.706,
#   'vader_pos': 0.141,
#   'vader_compound': 0.5425,
#   'Roberta_Negative_Review': 0.28926256,
#   'Roberta_Neutral_Review': 0.44554472,
#   'Roberta_Positive_Review': 0.2651928},
#  21: {'vader_neg': 0.198,
#   'vader_neu': 0.716,
#   'vader_pos': 0.086,
#   'vader_compound': -0.9755,
#   'Roberta_Negative_Review': 0.9779352,
#   'Roberta_Neutral_Review': 0.018928839,
#   'Roberta_Positive_Review': 0.0031360763},
#  22: {'vader_neg': 0.04,
#   'vader_neu': 0.794,
#   'vader_pos': 0.166,
#   'vader_compound': 0.7948,
#   'Roberta_Negative_Review': 0.0032595822,
#   'Roberta_Neutral_Review': 0.016052138,
#   'Roberta_Positive_Review': 0.98068815},
#  23: {'vader_neg': 0.114,
#   'vader_neu': 0.724,
#   'vader_pos': 0.162,
#   'vader_compound': 0.899,
#   'Roberta_Negative_Review': 0.79129964,
#   'Roberta_Neutral_Review': 0.15820636,
#   'Roberta_Positive_Review': 0.05049395},
#  24: {'vader_neg': 0.122,
#   'vader_neu': 0.797,
#   'vader_pos': 0.082,
#   'vader_compound': -0.7602,
#   'Roberta_Negative_Review': 0.85821366,
#   'Roberta_Neutral_Review': 0.11726915,
#   'Roberta_Positive_Review': 0.02451712},
#  25: {'vader_neg': 0.106,
#   'vader_neu': 0.667,
#   'vader_pos': 0.227,
#   'vader_compound': 0.954,
#   'Roberta_Negative_Review': 0.060101077,
#   'Roberta_Neutral_Review': 0.27281123,
#   'Roberta_Positive_Review': 0.6670878},
#  27: {'vader_neg': 0.184,
#   'vader_neu': 0.672,
#   'vader_pos': 0.144,
#   'vader_compound': -0.8481,
#   'Roberta_Negative_Review': 0.83798516,
#   'Roberta_Neutral_Review': 0.14058465,
#   'Roberta_Positive_Review': 0.021430159},
#  28: {'vader_neg': 0.24,
#   'vader_neu': 0.583,
#   'vader_pos': 0.177,
#   'vader_compound': -0.9208,
#   'Roberta_Negative_Review': 0.97054803,
#   'Roberta_Neutral_Review': 0.024958251,
#   'Roberta_Positive_Review': 0.0044938177},
#  31: {'vader_neg': 0.119,
#   'vader_neu': 0.781,
#   'vader_pos': 0.1,
#   'vader_compound': -0.6485,
#   'Roberta_Negative_Review': 0.11400004,
#   'Roberta_Neutral_Review': 0.46802473,
#   'Roberta_Positive_Review': 0.4179753},
#  32: {'vader_neg': 0.218,
#   'vader_neu': 0.702,
#   'vader_pos': 0.08,
#   'vader_compound': -0.9604,
#   'Roberta_Negative_Review': 0.4885479,
#   'Roberta_Neutral_Review': 0.3330465,
#   'Roberta_Positive_Review': 0.17840554},
#  34: {'vader_neg': 0.137,
#   'vader_neu': 0.715,
#   'vader_pos': 0.148,
#   'vader_compound': 0.7133,
#   'Roberta_Negative_Review': 0.74275315,
#   'Roberta_Neutral_Review': 0.19644888,
#   'Roberta_Positive_Review': 0.060797874},
#  35: {'vader_neg': 0.13,
#   'vader_neu': 0.763,
#   'vader_pos': 0.107,
#   'vader_compound': -0.9399,
#   'Roberta_Negative_Review': 0.559325,
#   'Roberta_Neutral_Review': 0.3569781,
#   'Roberta_Positive_Review': 0.08369682},
#  36: {'vader_neg': 0.221,
#   'vader_neu': 0.731,
#   'vader_pos': 0.048,
#   'vader_compound': -0.962,
#   'Roberta_Negative_Review': 0.96514404,
#   'Roberta_Neutral_Review': 0.031239282,
#   'Roberta_Positive_Review': 0.0036167307},
#  37: {'vader_neg': 0.163,
#   'vader_neu': 0.76,
#   'vader_pos': 0.077,
#   'vader_compound': -0.9847,
#   'Roberta_Negative_Review': 0.7727644,
#   'Roberta_Neutral_Review': 0.20132737,
#   'Roberta_Positive_Review': 0.02590822},
#  38: {'vader_neg': 0.05,
#   'vader_neu': 0.7,
#   'vader_pos': 0.25,
#   'vader_compound': 0.9838,
#   'Roberta_Negative_Review': 0.17523539,
#   'Roberta_Neutral_Review': 0.2690206,
#   'Roberta_Positive_Review': 0.555744},
#  39: {'vader_neg': 0.081,
#   'vader_neu': 0.747,
#   'vader_pos': 0.173,
#   'vader_compound': 0.9797,
#   'Roberta_Negative_Review': 0.79734993,
#   'Roberta_Neutral_Review': 0.17731535,
#   'Roberta_Positive_Review': 0.02533471},
#  40: {'vader_neg': 0.104,
#   'vader_neu': 0.79,
#   'vader_pos': 0.106,
#   'vader_compound': 0.0854,
#   'Roberta_Negative_Review': 0.8547,
#   'Roberta_Neutral_Review': 0.12547676,
#   'Roberta_Positive_Review': 0.019823164},
#  41: {'vader_neg': 0.03,
#   'vader_neu': 0.781,
#   'vader_pos': 0.189,
#   'vader_compound': 0.9858,
#   'Roberta_Negative_Review': 0.008102008,
#   'Roberta_Neutral_Review': 0.09048482,
#   'Roberta_Positive_Review': 0.901413},
#  42: {'vader_neg': 0.144,
#   'vader_neu': 0.732,
#   'vader_pos': 0.124,
#   'vader_compound': -0.4678,
#   'Roberta_Negative_Review': 0.82282436,
#   'Roberta_Neutral_Review': 0.15525876,
#   'Roberta_Positive_Review': 0.021916874},
#  43: {'vader_neg': 0.046,
#   'vader_neu': 0.814,
#   'vader_pos': 0.14,
#   'vader_compound': 0.9818,
#   'Roberta_Negative_Review': 0.71852994,
#   'Roberta_Neutral_Review': 0.23779061,
#   'Roberta_Positive_Review': 0.04367933},
#  44: {'vader_neg': 0.026,
#   'vader_neu': 0.846,
#   'vader_pos': 0.128,
#   'vader_compound': 0.9182,
#   'Roberta_Negative_Review': 0.1433462,
#   'Roberta_Neutral_Review': 0.4178944,
#   'Roberta_Positive_Review': 0.43875936},
#  45: {'vader_neg': 0.016,
#   'vader_neu': 0.891,
#   'vader_pos': 0.093,
#   'vader_compound': 0.9401,
#   'Roberta_Negative_Review': 0.014722989,
#   'Roberta_Neutral_Review': 0.102497734,
#   'Roberta_Positive_Review': 0.88277924},
#  46: {'vader_neg': 0.031,
#   'vader_neu': 0.775,
#   'vader_pos': 0.194,
#   'vader_compound': 0.9165,
#   'Roberta_Negative_Review': 0.6720444,
#   'Roberta_Neutral_Review': 0.2732199,
#   'Roberta_Positive_Review': 0.054735616},
#  47: {'vader_neg': 0.054,
#   'vader_neu': 0.917,
#   'vader_pos': 0.029,
#   'vader_compound': -0.68,
#   'Roberta_Negative_Review': 0.5483824,
#   'Roberta_Neutral_Review': 0.38960016,
#   'Roberta_Positive_Review': 0.062017582},
#  49: {'vader_neg': 0.141,
#   'vader_neu': 0.695,
#   'vader_pos': 0.165,
#   'vader_compound': 0.2152,
#   'Roberta_Negative_Review': 0.36273095,
#   'Roberta_Neutral_Review': 0.39873725,
#   'Roberta_Positive_Review': 0.2385317},
#  52: {'vader_neg': 0.147,
#   'vader_neu': 0.768,
#   'vader_pos': 0.085,
#   'vader_compound': -0.9274,
#   'Roberta_Negative_Review': 0.043381263,
#   'Roberta_Neutral_Review': 0.2717683,
#   'Roberta_Positive_Review': 0.68485045},
#  53: {'vader_neg': 0.05,
#   'vader_neu': 0.825,
#   'vader_pos': 0.125,
#   'vader_compound': 0.7416,
#   'Roberta_Negative_Review': 0.05164413,
#   'Roberta_Neutral_Review': 0.17523994,
#   'Roberta_Positive_Review': 0.773116},
#  54: {'vader_neg': 0.193,
#   'vader_neu': 0.699,
#   'vader_pos': 0.108,
#   'vader_compound': -0.968,
#   'Roberta_Negative_Review': 0.8927543,
#   'Roberta_Neutral_Review': 0.09760979,
#   'Roberta_Positive_Review': 0.009635772},
#  55: {'vader_neg': 0.098,
#   'vader_neu': 0.819,
#   'vader_pos': 0.083,
#   'vader_compound': -0.3696,
#   'Roberta_Negative_Review': 0.5975118,
#   'Roberta_Neutral_Review': 0.33082077,
#   'Roberta_Positive_Review': 0.07166744},
#  56: {'vader_neg': 0.122,
#   'vader_neu': 0.832,
#   'vader_pos': 0.046,
#   'vader_compound': -0.9477,
#   'Roberta_Negative_Review': 0.40475157,
#   'Roberta_Neutral_Review': 0.4018795,
#   'Roberta_Positive_Review': 0.19336876},
#  57: {'vader_neg': 0.114,
#   'vader_neu': 0.741,
#   'vader_pos': 0.145,
#   'vader_compound': 0.7648,
#   'Roberta_Negative_Review': 0.9190562,
#   'Roberta_Neutral_Review': 0.07234078,
#   'Roberta_Positive_Review': 0.008602951},
#  60: {'vader_neg': 0.091,
#   'vader_neu': 0.753,
#   'vader_pos': 0.157,
#   'vader_compound': 0.9139,
#   'Roberta_Negative_Review': 0.3818074,
#   'Roberta_Neutral_Review': 0.42138064,
#   'Roberta_Positive_Review': 0.19681202},
#  61: {'vader_neg': 0.047,
#   'vader_neu': 0.921,
#   'vader_pos': 0.031,
#   'vader_compound': -0.3699,
#   'Roberta_Negative_Review': 0.9427434,
#   'Roberta_Neutral_Review': 0.05261109,
#   'Roberta_Positive_Review': 0.0046455865},
#  62: {'vader_neg': 0.021,
#   'vader_neu': 0.862,
#   'vader_pos': 0.117,
#   'vader_compound': 0.7747,
#   'Roberta_Negative_Review': 0.007924771,
#   'Roberta_Neutral_Review': 0.045686495,
#   'Roberta_Positive_Review': 0.9463888},
#  63: {'vader_neg': 0.079,
#   'vader_neu': 0.876,
#   'vader_pos': 0.045,
#   'vader_compound': -0.168,
#   'Roberta_Negative_Review': 0.9411109,
#   'Roberta_Neutral_Review': 0.05316558,
#   'Roberta_Positive_Review': 0.0057234433},
#  64: {'vader_neg': 0.116,
#   'vader_neu': 0.772,
#   'vader_pos': 0.111,
#   'vader_compound': -0.4442,
#   'Roberta_Negative_Review': 0.76945114,
#   'Roberta_Neutral_Review': 0.19876209,
#   'Roberta_Positive_Review': 0.03178677},
#  65: {'vader_neg': 0.09,
#   'vader_neu': 0.785,
#   'vader_pos': 0.124,
#   'vader_compound': 0.6803,
#   'Roberta_Negative_Review': 0.20438008,
#   'Roberta_Neutral_Review': 0.5221729,
#   'Roberta_Positive_Review': 0.27344695},
#  66: {'vader_neg': 0.123,
#   'vader_neu': 0.759,
#   'vader_pos': 0.118,
#   'vader_compound': -0.6416,
#   'Roberta_Negative_Review': 0.45774493,
#   'Roberta_Neutral_Review': 0.435585,
#   'Roberta_Positive_Review': 0.10667014},
#  67: {'vader_neg': 0.014,
#   'vader_neu': 0.731,
#   'vader_pos': 0.255,
#   'vader_compound': 0.9902,
#   'Roberta_Negative_Review': 0.08713727,
#   'Roberta_Neutral_Review': 0.2871537,
#   'Roberta_Positive_Review': 0.62570906},
#  68: {'vader_neg': 0.045,
#   'vader_neu': 0.885,
#   'vader_pos': 0.069,
#   'vader_compound': 0.7073,
#   'Roberta_Negative_Review': 0.54513776,
#   'Roberta_Neutral_Review': 0.38112146,
#   'Roberta_Positive_Review': 0.07374084},
#  69: {'vader_neg': 0.057,
#   'vader_neu': 0.833,
#   'vader_pos': 0.11,
#   'vader_compound': 0.9422,
#   'Roberta_Negative_Review': 0.40168142,
#   'Roberta_Neutral_Review': 0.43447584,
#   'Roberta_Positive_Review': 0.16384278},
#  70: {'vader_neg': 0.072,
#   'vader_neu': 0.737,
#   'vader_pos': 0.19,
#   'vader_compound': 0.9837,
#   'Roberta_Negative_Review': 0.6324403,
#   'Roberta_Neutral_Review': 0.26734918,
#   'Roberta_Positive_Review': 0.10021045},
#  71: {'vader_neg': 0.094,
#   'vader_neu': 0.715,
#   'vader_pos': 0.192,
#   'vader_compound': 0.9852,
#   'Roberta_Negative_Review': 0.43296242,
#   'Roberta_Neutral_Review': 0.36055428,
#   'Roberta_Positive_Review': 0.2064833},
#  72: {'vader_neg': 0.074,
#   'vader_neu': 0.832,
#   'vader_pos': 0.094,
#   'vader_compound': 0.6441,
#   'Roberta_Negative_Review': 0.047615703,
#   'Roberta_Neutral_Review': 0.20404828,
#   'Roberta_Positive_Review': 0.748336},
#  73: {'vader_neg': 0.043,
#   'vader_neu': 0.783,
#   'vader_pos': 0.175,
#   'vader_compound': 0.9813,
#   'Roberta_Negative_Review': 0.027260482,
#   'Roberta_Neutral_Review': 0.26411504,
#   'Roberta_Positive_Review': 0.7086245},
#  74: {'vader_neg': 0.033,
#   'vader_neu': 0.871,
#   'vader_pos': 0.096,
#   'vader_compound': 0.9382,
#   'Roberta_Negative_Review': 0.15937287,
#   'Roberta_Neutral_Review': 0.48104072,
#   'Roberta_Positive_Review': 0.35958636},
#  75: {'vader_neg': 0.021,
#   'vader_neu': 0.735,
#   'vader_pos': 0.244,
#   'vader_compound': 0.9847,
#   'Roberta_Negative_Review': 0.026369533,
#   'Roberta_Neutral_Review': 0.11574825,
#   'Roberta_Positive_Review': 0.8578822},
#  76: {'vader_neg': 0.129,
#   'vader_neu': 0.771,
#   'vader_pos': 0.1,
#   'vader_compound': -0.8963,
#   'Roberta_Negative_Review': 0.66567975,
#   'Roberta_Neutral_Review': 0.3056754,
#   'Roberta_Positive_Review': 0.028644864},
#  78: {'vader_neg': 0.075,
#   'vader_neu': 0.816,
#   'vader_pos': 0.109,
#   'vader_compound': 0.4082,
#   'Roberta_Negative_Review': 0.7341607,
#   'Roberta_Neutral_Review': 0.2272433,
#   'Roberta_Positive_Review': 0.038595848},
#  79: {'vader_neg': 0.07,
#   'vader_neu': 0.837,
#   'vader_pos': 0.093,
#   'vader_compound': 0.8498,
#   'Roberta_Negative_Review': 0.013828626,
#   'Roberta_Neutral_Review': 0.10051051,
#   'Roberta_Positive_Review': 0.88566095},
#  80: {'vader_neg': 0.039,
#   'vader_neu': 0.81,
#   'vader_pos': 0.151,
#   'vader_compound': 0.9714,
#   'Roberta_Negative_Review': 0.0268145,
#   'Roberta_Neutral_Review': 0.11846688,
#   'Roberta_Positive_Review': 0.85471857},
#  81: {'vader_neg': 0.166,
#   'vader_neu': 0.756,
#   'vader_pos': 0.078,
#   'vader_compound': -0.9504,
#   'Roberta_Negative_Review': 0.9216948,
#   'Roberta_Neutral_Review': 0.06934983,
#   'Roberta_Positive_Review': 0.00895532},
#  82: {'vader_neg': 0.162,
#   'vader_neu': 0.69,
#   'vader_pos': 0.148,
#   'vader_compound': -0.8837,
#   'Roberta_Negative_Review': 0.8084991,
#   'Roberta_Neutral_Review': 0.15993492,
#   'Roberta_Positive_Review': 0.031566024},
#  83: {'vader_neg': 0.133,
#   'vader_neu': 0.721,
#   'vader_pos': 0.146,
#   'vader_compound': 0.5907,
#   'Roberta_Negative_Review': 0.877801,
#   'Roberta_Neutral_Review': 0.10750761,
#   'Roberta_Positive_Review': 0.014691535},
#  84: {'vader_neg': 0.186,
#   'vader_neu': 0.712,
#   'vader_pos': 0.102,
#   'vader_compound': -0.8489,
#   'Roberta_Negative_Review': 0.9758892,
#   'Roberta_Neutral_Review': 0.02102113,
#   'Roberta_Positive_Review': 0.0030896354},
#  85: {'vader_neg': 0.159,
#   'vader_neu': 0.758,
#   'vader_pos': 0.083,
#   'vader_compound': -0.9123,
#   'Roberta_Negative_Review': 0.9808668,
#   'Roberta_Neutral_Review': 0.016536972,
#   'Roberta_Positive_Review': 0.0025962885},
#  86: {'vader_neg': 0.105,
#   'vader_neu': 0.791,
#   'vader_pos': 0.104,
#   'vader_compound': -0.1012,
#   'Roberta_Negative_Review': 0.37397283,
#   'Roberta_Neutral_Review': 0.45256665,
#   'Roberta_Positive_Review': 0.17346065},
#  87: {'vader_neg': 0.116,
#   'vader_neu': 0.787,
#   'vader_pos': 0.097,
#   'vader_compound': -0.4623,
#   'Roberta_Negative_Review': 0.5801263,
#   'Roberta_Neutral_Review': 0.32993132,
#   'Roberta_Positive_Review': 0.089942545},
#  88: {'vader_neg': 0.152,
#   'vader_neu': 0.718,
#   'vader_pos': 0.13,
#   'vader_compound': -0.7228,
#   'Roberta_Negative_Review': 0.7237845,
#   'Roberta_Neutral_Review': 0.24307631,
#   'Roberta_Positive_Review': 0.033139143},
#  89: {'vader_neg': 0.148,
#   'vader_neu': 0.748,
#   'vader_pos': 0.104,
#   'vader_compound': -0.9659,
#   'Roberta_Negative_Review': 0.564644,
#   'Roberta_Neutral_Review': 0.35569933,
#   'Roberta_Positive_Review': 0.07965662},
#  90: {'vader_neg': 0.033,
#   'vader_neu': 0.851,
#   'vader_pos': 0.116,
#   'vader_compound': 0.9311,
#   'Roberta_Negative_Review': 0.0020274578,
#   'Roberta_Neutral_Review': 0.028448526,
#   'Roberta_Positive_Review': 0.96952397},
#  91: {'vader_neg': 0.068,
#   'vader_neu': 0.855,
#   'vader_pos': 0.077,
#   'vader_compound': -0.0516,
#   'Roberta_Negative_Review': 0.8376129,
#   'Roberta_Neutral_Review': 0.13871731,
#   'Roberta_Positive_Review': 0.023669606},
#  93: {'vader_neg': 0.052,
#   'vader_neu': 0.736,
#   'vader_pos': 0.212,
#   'vader_compound': 0.9818,
#   'Roberta_Negative_Review': 0.012106279,
#   'Roberta_Neutral_Review': 0.2425972,
#   'Roberta_Positive_Review': 0.74529654},
#  94: {'vader_neg': 0.033,
#   'vader_neu': 0.843,
#   'vader_pos': 0.125,
#   'vader_compound': 0.9272,
#   'Roberta_Negative_Review': 0.42204875,
#   'Roberta_Neutral_Review': 0.46826288,
#   'Roberta_Positive_Review': 0.10968823},
#  95: {'vader_neg': 0.086,
#   'vader_neu': 0.735,
#   'vader_pos': 0.179,
#   'vader_compound': 0.9826,
#   'Roberta_Negative_Review': 0.038287643,
#   'Roberta_Neutral_Review': 0.17748567,
#   'Roberta_Positive_Review': 0.7842267},
#  96: {'vader_neg': 0.167,
#   'vader_neu': 0.735,
#   'vader_pos': 0.099,
#   'vader_compound': -0.9434,
#   'Roberta_Negative_Review': 0.41143638,
#   'Roberta_Neutral_Review': 0.41244462,
#   'Roberta_Positive_Review': 0.17611891},
#  97: {'vader_neg': 0.324,
#   'vader_neu': 0.547,
#   'vader_pos': 0.13,
#   'vader_compound': -0.9882,
#   'Roberta_Negative_Review': 0.8421043,
#   'Roberta_Neutral_Review': 0.12051555,
#   'Roberta_Positive_Review': 0.03738003},
#  98: {'vader_neg': 0.203,
#   'vader_neu': 0.729,
#   'vader_pos': 0.068,
#   'vader_compound': -0.9876,
#   'Roberta_Negative_Review': 0.9445878,
#   'Roberta_Neutral_Review': 0.049333654,
#   'Roberta_Positive_Review': 0.0060785552}}

# %% [markdown]
# # *Review Sentiment Analysis Results (roBERTa vs Vader)*

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns={'index': 'Movie Id'})
results_df
# Out:
#     Movie Id  vader_neg  vader_neu  vader_pos  vader_compound  \
# 0          0      0.203      0.748      0.048         -0.9951
# 1          1      0.053      0.776      0.172          0.9641
# 2          2      0.094      0.714      0.192          0.9605
# 3          3      0.138      0.797      0.065         -0.9213
# 4          4      0.052      0.801      0.147          0.9744
# ..       ...        ...        ...        ...             ...
# 82        94      0.033      0.843      0.125          0.9272
# 83        95      0.086      0.735      0.179          0.9826
# 84        96      0.167      0.735      0.099         -0.9434
# 85        97      0.324      0.547      0.130         -0.9882
# 86        98      0.203      0.729      0.068         -0.9876
#
#     Roberta_Negative_Review  Roberta_Neutral_Review  Roberta_Positive_Review
# 0                  0.339792                0.462738                 0.197470
# 1                  0.004337                0.039048                 0.956615
# 2                  0.088475                0.263144                 0.648381
# 3                  0.755117                0.211640                 0.033243
# 4                  0.024546                0.223598                 0.751856
# ..                      ...                     ...                      ...
# 82                 0.422049                0.468263                 0.109688
# 83                 0.038288                0.177486                 0.784227
# 84                 0.411436                0.412445                 0.176119
# 85                 0.842104                0.120516                 0.037380
# 86                 0.944588                0.049334                 0.006079
#
# [87 rows x 8 columns]

# %% [markdown]
# # *Shawshank Redemption Example (roBERTa)*

# %% [markdown]
# ***“GET BUSY LIVIN',OR GET BUSY DYIN'”***

# %%
df_shawshank = pd.read_csv('Shawshank.csv')
df_shawshank
# Out:
#                                            Unnamed: 0  \
# 0   The Shawshank Redemption is written and direct...
# 1   It is no wonder that the film has such a high ...
# 2   I'm trying to save you money; this is the last...
# 3   This movie is not your ordinary Hollywood flic...
# 4   In its Oscar year, Shawshank Redemption (writt...
# 5   One of the finest films made in recent years. ...
# 6   Misery and Stand By Me were the best adaptatio...
# 7   I've lost count of the number of times I have ...
# 8   Two imprisoned men (Tim Robbins and Morgan Fre...
# 9   Based on a novella by Stephen King, this is be...
# 10  The best movie in history and the best ending ...
# 11  The Shawshank Redemption has great performance...
# 12  None of the usual otherworld creatures that po...
# 13  Well I guess I'm a little late to the party as...
# 14  Whenever I talk about this movie with my frien...
# 15  The Shawshank Redemption is without a doubt on...
# 16  I have never seen such an amazing film since I...
# 17  Can Hollywood, usually creating things for ent...
# 18  "The Shawshank Redemption" should have won Bes...
# 19  From PASTO, COLOMBIA-Via: L. A. CA; CALI, COLO...
# 20  Shawshank Redemption, The (1994)**** (out of 4...
# 21  One of my favorite movies ever,The Shawshank R...
# 22  The reason I became a member of this database ...
# 23  not for a reason. but for the fine art to crea...
# 24  **Yes, there are SPOILERS here**This film has ...
#
#                                            Sentiments
# 0                Some birds aren't meant to be caged.
# 1       An incredible movie. One that lives with you.
# 2                               Don't Rent Shawshank.
# 3                   This is How Movies Should Be Made
# 4       A classic piece of unforgettable film-making.
# 5                            The Shawshank Redemption
# 6                   Stephen King's best adapted movie
# 7                                        Eternal Hope
# 8              IMDb and the Greatest Film of All Time
# 9                        All-time prison film classic
# 10                           the shawshank redemption
# 11                     My favorite movie of all time.
# 12     "I Had To Go To Prison To Learn To Be A Crook"
# 13  "I'm a convicted murderer who provides sound f...
# 14                        Simply known as "The Movie"
# 15         Simply amazing. The best film of the 90's.
# 16                                Prepare to be moved
# 17                        Shawshank Redeems Hollywood
# 18                                 never give up hope
# 19  The UNIVERSALITY of Shawshank: Andy Dufresne a...
# 20                                        Masterpiece
# 21  Hope can set you free and so can this remarkab...
# 22                                  Two movies in one
# 23                                         impressive
# 24                         Busy dying or busy living?

# %%
res_shawshank = {}
for i, row in tqdm(df_shawshank.iterrows(), total=len(df_shawshank)):
    try:
        text = row['Sentiments']
        myid = i
               
        roberta_result_shawshank = polarity_scores_roberta(text)
        
        res_shawshank[i] = roberta_result_shawshank
    except RuntimeError:
        print(f'Broke for id {i}')
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
results_df_shawshank = pd.DataFrame(res_shawshank).T
results_df_shawshank = results_df_shawshank.reset_index().rename(columns={'index': 'Review Id'})
results_df_shawshank
# Out:
#     Review Id  Roberta_Negative_Review  Roberta_Neutral_Review  \
# 0           0                 0.548712                0.431967
# 1           1                 0.001931                0.030211
# 2           2                 0.326210                0.642881
# 3           3                 0.038695                0.441816
# 4           4                 0.006580                0.153588
# 5           5                 0.045000                0.848058
# 6           6                 0.003044                0.060496
# 7           7                 0.012179                0.455073
# 8           8                 0.007781                0.210001
# 9           9                 0.046544                0.555745
# 10         10                 0.068238                0.862910
# 11         11                 0.001706                0.017316
# 12         12                 0.808185                0.181084
# 13         13                 0.450917                0.491043
# 14         14                 0.092483                0.834502
# 15         15                 0.002272                0.016181
# 16         16                 0.104444                0.830750
# 17         17                 0.109284                0.862606
# 18         18                 0.141243                0.511411
# 19         19                 0.068093                0.848473
# 20         20                 0.105146                0.747427
# 21         21                 0.002681                0.064980
# 22         22                 0.106742                0.746947
# 23         23                 0.011719                0.155516
# 24         24                 0.442662                0.513939
#
#     Roberta_Positive_Review
# 0                  0.019320
# 1                  0.967857
# 2                  0.030909
# 3                  0.519490
# 4                  0.839832
# 5                  0.106942
# 6                  0.936461
# 7                  0.532748
# 8                  0.782218
# 9                  0.397711
# 10                 0.068853
# 11                 0.980979
# 12                 0.010731
# 13                 0.058039
# 14                 0.073015
# 15                 0.981548
# 16                 0.064806
# 17                 0.028110
# 18                 0.347346
# 19                 0.083434
# 20                 0.147427
# 21                 0.932339
# 22                 0.146311
# 23                 0.832765
# 24                 0.043399

# %% [markdown]
# # *Now let us use the pipeline from transformers*

# %%
from transformers import pipeline

sent_pipeline = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %% [markdown]
# **The Ultimate Vibe Test !**

# %%
sent_pipeline("TOUNIZI WINS THE WORLD CUP GALLOU FRANCA W GALLOU DENMARK")
sent_pipeline("AMDOUNI BEST WEHED FEL MUNDO")
# Out:
# [{'label': 'POSITIVE', 'score': 0.94375079870224}]
